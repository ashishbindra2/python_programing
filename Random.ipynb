# %% [markdown]
# RandInt
# -----------
# - randint internally called randrange,
# - 0-10 include 10 also
# - Return random integer in range [a, b], including both end points.

# %%
from random import randint,randrange

for _ in range(0,100):
    ran = randint(0,10)
    print(ran,end=',')
# Out:
# 5,1,7,7,8,3,2,9,9,4,6,9,4,5,8,1,2,2,5,8,6,7,2,10,5,6,2,7,10,5,6,3,8,4,3,10,4,0,9,4,10,2,4,7,3,8,0,2,7,4,0,8,8,6,2,2,8,8,2,6,2,6,5,0,7,10,2,4,3,0,0,10,5,2,0,6,4,2,2,6,4,6,3,2,3,0,2,0,4,10,7,6,8,7,9,3,5,0,5,10,

# %% [markdown]
# RandRange
# -----------------
# - Roughly equivalent to choice(range(start, stop, step)) but supports arbitrarily large ranges and is optimized for common cases.

# %%
from random import randint,randrange

for _ in range(0,100):
    ran = randrange(0,10)
    print(ran,end=',')
# Out:
# 5,3,9,4,5,9,5,0,7,6,3,1,8,4,1,1,6,2,9,2,0,4,9,9,6,9,6,9,0,6,4,5,5,3,4,4,7,0,2,6,3,4,1,9,6,7,4,2,4,9,0,4,2,1,0,0,7,5,5,3,1,8,7,3,7,9,8,0,3,8,0,5,3,2,9,2,7,7,4,8,2,2,7,3,5,9,9,8,9,9,5,4,1,6,0,8,4,4,7,0,

# %% [markdown]
# Choice
# -------
# Choose a random element from a non-empty list

# %%
from random import choice

random_name = ["ashish","sreshti","bindra","mui"]

for _ in range(1,4):
    print(choice(random_name))
# Out:
# sreshti
# sreshti
# sreshti

# %% [markdown]
#  choices
#  -----
#
#  Syntax : random.choices(sequence, weights=None, cum_weights=None, k=1)

# %%
from random import choices

random_name = ["ashish","sreshti","bindra","mui"]

for _ in range(3):
    print(choices(random_name))
# Out:
# ['mui']
# ['bindra']
# ['ashish']

# %%
from random import choices

random_name = ["ashish","sreshti","bindra","mui"]

for _ in range(3):
    print(choices(random_name,k=2))
# Out:
# ['ashish', 'ashish']
# ['ashish', 'sreshti']
# ['sreshti', 'bindra']

# %%
from random import choices

random_name = ["ashish","sreshti","bindra","mui"]

for _ in range(3):
    print(choices(random_name,weights=[2,3,1,1],k=2))
# weights 2 for sreshti meanse sreshti will come more likly to be first
# Out:
# ['sreshti', 'bindra']
# ['sreshti', 'bindra']
# ['sreshti', 'sreshti']

# %% [markdown]
# random
# --------
# Parameters : This method does not accept any parameter.
#
# Returns : This method returns a random floating number between 0 and 1.

# %%
from random import random

for _ in range(10):
    print(random())


print(f'{"end":*^20}')

for _ in range(10):
    ten = random()*100
    print(f'{ten:.2f}')
# Out:
# 0.17022770604144655
# 0.5765035047832664
# 0.9824183546550068
# 0.9040092384111674
# 0.1799873892325332
# 0.784792038659979
# 0.12057587030483241
# 0.2627924728275056
# 0.34680542486498567
# 0.005190363681647381
# ********end*********
# 12.46
# 66.63
# 83.47
# 3.02
# 28.00
# 57.82
# 91.58
# 16.87
# 93.74
# 97.93

# %%
from datetime import datetime

datetime.today().year
# Out:
# 2024

# %%
from random import randint,randrange
help(randrange)
# Out:
# Help on method randrange in module random:
#
# randrange(start, stop=None, step=1) method of random.Random instance
#     Choose a random item from range(stop) or range(start, stop[, step]).
#
#     Roughly equivalent to ``choice(range(start, stop, step))`` but
#     supports arbitrarily large ranges and is optimized for common cases.

# %%
from random import choices

random_numbers = list(range(0,101))
# print(random_numbers)
weights = [1] * 101
weights[29]=100
weights[51]=100

# print(weights)
for _ in range(3):
    print(choices(random_numbers,weights=weights,k=1))
# Out:
# [51]
# [51]
# [51]

# %%
import http.client

conn = http.client.HTTPSConnection("instagram-scraper-api2.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "339540eaebmshd81a38080a76548p120292jsn22d6b283a5ae",
    'x-rapidapi-host': "instagram-scraper-api2.p.rapidapi.com"
}

conn.request("GET", "/v1/likes?code_or_id_or_url=CxYQJO8xuC6", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"data":{"count":880,"items":[{"full_name":"","id":"65254200045","is_new":false,"is_private":true,"is_verified":false,"latest_reel_media":0,"profile_pic_url":"https://instagram.frwn2-1.fna.fbcdn.net/v/t51.2885-19/44884218_345707102882519_2446069589734326272_n.jpg?_nc_ht=instagram.frwn2-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=WdPvrJF7xMMQ7kNvgGBLsVm&edm=AEsR1pMBAAAA&ccb=7-5&ig_cache_key=YW5vbnltb3VzX3Byb2ZpbGVfcGlj.2-ccb7-5&oh=00_AYAeKt0CMXUTLB9bZVbFP6bcKRjW6mMTYev-rWV4UUNXaQ&oe=666AFECF&_nc_sid=e2f88a","username":"ohnlephorphun"},{"full_name":"Gita Salmasi","id":"1636734814","is_new":false,"is_private":true,"is_verified":false,"latest_reel_media":0,"profile_pic_id":"3336355175960785963","profile_pic_url":"https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/434940037_387691347439852_408040972351372625_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=104&_nc_ohc=RxVLO8dCHjcQ7kNvgF0felY&edm=AHUBisUBAAAA&ccb=7-5&oh=00_AYCLHEu7GTas4kXxKfXG0fzHoh-377Ku1Az_0Kwsg-nr
# ...

# %%
import http.client

conn = http.client.HTTPSConnection("one-piece-episodes.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "339540eaebmshd81a38080a76548p120292jsn22d6b283a5ae",
    'x-rapidapi-host': "one-piece-episodes.p.rapidapi.com"
}

conn.request("GET", "/one_piece/episode/%7Bnumber%7D?number=35&language=es", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"messages":"The API is unreachable, please contact the API provider", "info": "Your Client (working) ---> Gateway (working) ---> API (not working)"}
